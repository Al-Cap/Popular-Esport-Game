# %%
import matplotlib
import xlrd
import pandas as pd

data = pd.read_excel("../data/EsportCorrected.xlsx")
data
# Out:
#                                Game  ReleaseDate                 Genre  \
# 0                    Age of Empires         1997              Strategy
# 1                 Age of Empires II         1999              Strategy
# 2                Age of Empires III         2005              Strategy
# 3             Age of Empires Online         2011              Strategy
# 4                  Age of Mythology         2002              Strategy
# ..                              ...          ...                   ...
# 487                    Gears of War         2006  Third-Person Shooter
# 488                  Gears of War 2         2008  Third-Person Shooter
# 489                  Gears of War 3         2011  Third-Person Shooter
# 490                  Gears of War 4         2016  Third-Person Shooter
# 491  Gears of War: Ultimate Edition         2015  Third-Person Shooter
#
#      TotalEarnings  OnlineEarnings  TotalPlayers  TotalTournaments
# ...
