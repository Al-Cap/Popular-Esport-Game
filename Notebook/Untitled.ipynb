# %%
## using xlrd to read excel files
## using pandas to import and show data in table formate
import matplotlib.pyplot as plt
import numpy as np
import xlrd
import pandas as pd

## data is imported from an excel file
data = pd.read_excel("../data/EsportCorrected_1.xlsx")
data
# Out:
#                                Game  ReleaseDate                 Genre  \
# 0                Age of Empires III         2005              Strategy
# 1             Age of Empires Online         2011              Strategy
# 2                  Age of Mythology         2002              Strategy
# 3                        Auto Chess         2019              Strategy
# 4                       Brawl Stars         2018              Strategy
# ..                              ...          ...                   ...
# 448                    Gears of War         2006  Third-Person Shooter
# 449                  Gears of War 2         2008  Third-Person Shooter
# 450                  Gears of War 3         2011  Third-Person Shooter
# 451                  Gears of War 4         2016  Third-Person Shooter
# 452  Gears of War: Ultimate Edition         2015  Third-Person Shooter
#
#      TotalEarnings  OnlineEarnings  TotalPlayers  TotalTournaments
# ...

# %%
# compiling data to show the limitatins of the data
data.describe()
# Out:
#        ReleaseDate  TotalEarnings  OnlineEarnings  TotalPlayers  \
# count   453.000000   4.530000e+02    4.530000e+02    453.000000
# mean   2012.059603   1.863059e+06    3.271524e+05    194.779249
# std       5.622606   1.320094e+07    2.859632e+06    825.070166
# min    2000.000000   0.000000e+00    0.000000e+00      0.000000
# 25%    2007.000000   1.395970e+03    0.000000e+00      3.000000
# 50%    2013.000000   3.744566e+04    0.000000e+00     20.000000
# 75%    2017.000000   2.244670e+05    8.700000e+03     86.000000
# max    2020.000000   2.260857e+08    5.231200e+07  12981.000000
#
#        TotalTournaments
# count        453.000000
# mean          84.885210
# std          429.580779
# min            0.000000
# 25%            1.000000
# 50%            5.000000
# 75%           28.000000
# max         5891.000000

# %%
# show data types used
list(set(data.dtypes))
# Out:
# [dtype('O'), dtype('int64'), dtype('float64')]

# %%
# list data columns
data.columns.to_list()
# Out:
# ['Game',
#  'ReleaseDate',
#  'Genre',
#  'TotalEarnings',
#  'OnlineEarnings',
#  'TotalPlayers',
#  'TotalTournaments']

# %%
# list Game column's index
data.Game.to_list()
# Out:
# ['Age of Empires III',
#  'Age of Empires Online',
#  'Age of Mythology',
#  'Auto Chess',
#  'Brawl Stars',
#  'Chess.com',
#  'chess24',
#  'Clash of Clans',
#  'Clash Royale',
#  'Command & Conquer 3',
#  'Company of Heroes 2',
#  'ComPet',
#  'Dota Underlords',
#  'Endgods',
#  'Farming Simulator 19',
#  'Grey Goo',
#  'Iron Harvest',
#  'Lichess',
#  'Multigaming',
#  'osu!',
#  'Playchess.com',
#  'Pokémon VGC',
#  'Prophecy',
#  'Rise of Nations: Rise of Legends',
#  'Sea of Thieves',
#  'StarCraft II',
#  'Super Mario Party',
#  'Supreme Commander',
#  'Supreme Commander: Forged Alliance',
#  'Teamfight Tactics',
#  'TEPPEN',
#  'UNO',
#  'WarCraft III',
#  'WarCraft III: Reforged',
#  'Warhammer 40,000: Dawn of War',
#  'Warhammer 40,000: Dawn of War II',
#  'Warparty',
#  'World in Conflict',
#  'World of Tanks',
#  'World of Tanks Blitz',
#  'Aliens versus Predator 2',
#  'Battalion 1944',
#  'Battlefield 1',
#  'Battlefield 2',
#  'Battlefield 2142',
#  'Battlefield 3',
# ...

# %%
# list Genre column's index
data.Genre.to_list()
# Out:
# ['Strategy',
#  'Strategy',
#  'Strategy',
#  'Strategy',
#  'Strategy',
#  'Strategy',
#  'Strategy',
#  'Strategy',
#  'Strategy',
#  'Strategy',
#  'Strategy',
#  'Strategy',
#  'Strategy',
#  'Strategy',
#  'Strategy',
#  'Strategy',
#  'Strategy',
#  'Strategy',
#  'Strategy',
#  'Strategy',
#  'Strategy',
#  'Strategy',
#  'Strategy',
#  'Strategy',
#  'Strategy',
#  'Strategy',
#  'Strategy',
#  'Strategy',
#  'Strategy',
#  'Strategy',
#  'Strategy',
#  'Strategy',
#  'Strategy',
#  'Strategy',
#  'Strategy',
#  'Strategy',
#  'Strategy',
#  'Strategy',
#  'Strategy',
#  'Strategy',
#  'First-Person Shooter',
#  'First-Person Shooter',
#  'First-Person Shooter',
#  'First-Person Shooter',
#  'First-Person Shooter',
#  'First-Person Shooter',
#  'First-Person Shooter',
#  'First-Person Shooter',
#  'First-Person Shooter',
#  'First-Person Shooter',
#  'First-Person Shooter',
#  'First-Person Shooter',
#  'First-Person Shooter',
#  'First-Person Shooter',
# ...

# %%
# list Release Date column's index
data.ReleaseDate.to_list()
# Out:
# [2005,
#  2011,
#  2002,
#  2019,
#  2018,
#  2007,
#  2014,
#  2012,
#  2016,
#  2007,
#  2013,
#  2016,
#  2019,
#  2015,
#  2018,
#  2015,
#  2020,
#  2010,
#  2000,
#  2007,
#  2002,
#  2017,
#  2020,
#  2006,
#  2016,
#  2010,
#  2018,
#  2007,
#  2007,
#  2019,
#  2019,
#  2016,
#  2002,
#  2020,
#  2005,
#  2009,
#  2019,
#  2007,
#  2010,
#  2016,
#  2001,
#  2018,
#  2016,
#  2005,
#  2006,
#  2011,
#  2013,
#  2018,
#  2015,
#  2019,
#  2016,
#  2017,
#  2019,
#  2003,
#  2005,
#  2007,
#  2014,
#  2010,
#  2012,
#  2018,
#  2015,
#  2013,
#  2016,
#  2019,
#  2019,
#  2009,
#  2011,
#  2020,
#  2017,
#  2000,
#  2016,
#  2004,
#  2012,
#  2004,
#  2015,
#  2007,
#  2007,
#  2003,
#  2005,
#  2020,
#  2016,
#  2004,
#  2017,
#  2007,
#  2020,
#  2015,
#  2005,
#  2006,
#  2015,
#  2017,
#  2017,
#  2004,
#  2014,
#  2007,
#  2012,
#  2015,
#  2001,
#  2020,
#  2010,
#  2018,
#  2017,
#  2013,
#  2008,
#  2016,
#  2004,
#  2015,
#  2008,
#  2005,
#  2017,
#  2010,
#  2011,
# ...

# %%
# list Total Earnings column's index
data.TotalEarnings.to_list()
# Out:
# [66463.85,
#  2668.0,
#  52360.0,
#  1076322.28,
#  94950.0,
#  774490.96,
#  1084696.09,
#  765216.87,
#  3319748.27,
#  53086.67,
#  8561.22,
#  2000.0,
#  26024.18,
#  0.0,
#  158361.3,
#  36400.0,
#  0.0,
#  419825.0,
#  148384.33,
#  23100.0,
#  32866.58,
#  211500.0,
#  13000.0,
#  69600.0,
#  0.0,
#  33479094.16,
#  220.0,
#  4901.26,
#  1290.01,
#  604313.65,
#  456721.47,
#  20000.0,
#  5811479.73,
#  167036.45,
#  79816.5,
#  0.0,
#  1000.0,
#  293338.23,
#  3656496.59,
#  63330.0,
#  40000.0,
#  185654.67,
#  0.0,
#  91715.22,
#  18546.14,
#  25407.46,
#  245766.46,
#  0.0,
#  13463.28,
#  0.0,
#  76200.0,
#  8480.72,
#  0.0,
#  50629.77,
#  66828.51,
#  420331.47,
#  2608808.93,
#  375793.48,
#  1467139.25,
#  7270138.95,
#  3939783.29,
#  1594185.25,
#  4156205.06,
#  0.0,
#  1837284.5,
#  112860.64,
#  1160815.66,
#  1504638.96,
#  4559271.0,
#  13492961.87,
#  406989.6,
#  162150.6,
#  100689160.41,
#  3117222.29,
#  12606.41,
#  6448845.02,
#  11340.95,
#  50300.0,
# ...

# %%
# set variables for earnings and genre
total_earnings = data.TotalEarnings.to_list()
genre = data.Genre.to_list()

# graphing in horizontal bar graph of genre and earngings
plt.barh(genre, total_earnings)
plt.xlabel('Total Earnings [milions]')
plt.ylabel('Genre')
plt.title('Earnings Per Genre')
plt.savefig('../figures/genre-tearn_barh.png')

# %%
# set variables for release date and tournaments
rel = data.ReleaseDate.to_list()
tour = data.TotalTournaments.to_list()

# graphing in bar graph of release date and tournaments
plt.bar(rel, tour)
plt.xlabel('Release Date of Games')
plt.ylabel('Total Tournaments')
plt.title('Tournaments Per Year')
plt.savefig('../figures/tour-rel_bar.png')

# %%
# set variables for total players
ply = data.TotalPlayers.to_list()

# graphing in horizontal bar graph of total players and genre
plt.barh(genre, ply)
plt.xlabel('Total Players')
plt.ylabel('Genre')
plt.title('Players Per Genre')
plt.savefig('../figures/genre-ply_barh.png')

# %%
# compressed data to view only first-person shooter games
# assigned to a new variable
ds = data[data.Genre == 'First-Person Shooter']
ds = ds[ds.TotalPlayers > 1000]
ds
# Out:
#                                  Game  ReleaseDate                 Genre  \
# 69                     Counter-Strike         2000  First-Person Shooter
# 72   Counter-Strike: Global Offensive         2012  First-Person Shooter
# 73             Counter-Strike: Source         2004  First-Person Shooter
# 103                         Overwatch         2016  First-Person Shooter
# 111                 Rainbow Six Siege         2015  First-Person Shooter
# 126                   Team Fortress 2         2007  First-Person Shooter
# 132                          VALORANT         2020  First-Person Shooter
#
#      TotalEarnings  OnlineEarnings  TotalPlayers  TotalTournaments
# 69    1.349296e+07       713229.74          4137               994
# 72    1.006892e+08     26004120.57         12981              5172
# 73    3.117222e+06       240456.26          1504               333
# 103   2.204933e+07      3822852.83          3494               740
# ...

# %%
# set variable for gaame under the new data set
# redefined total players under new data set
gs = ds.Game.to_list()
ps = ds.TotalPlayers.to_list()

# graphing in horizontal bar graph of players and games
plt.barh(gs, ps)
plt.xlabel('Players')
plt.ylabel('Game')
plt.title('Players Per Game')
plt.savefig('../figures/FirstP-Shooter_game-player_barh')

# %%
# graphing in horizontal bar graph of genres and tournaments
plt.barh(genre, tour)
plt.ylabel('Genre')
plt.xlabel('Total Tournaments')
plt.title('Tournaments Per Genres')
plt.savefig('../figures/genre-tour_barh.png')

# %%
# compiled new data data set for strategy games only
# defined new set with variable
data[data.Genre == 'Strategy']
dg = data[data.Genre == 'Strategy']
dg[dg.TotalTournaments > 50]
dg = dg[dg.TotalTournaments > 50]
dg
# Out:
#                       Game  ReleaseDate     Genre  TotalEarnings  \
# 0       Age of Empires III         2005  Strategy       66463.85
# 5                Chess.com         2007  Strategy      774490.96
# 17                 Lichess         2010  Strategy      419825.00
# 25            StarCraft II         2010  Strategy    33479094.16
# 32            WarCraft III         2002  Strategy     5811479.73
# 33  WarCraft III: Reforged         2020  Strategy      167036.45
#
#     OnlineEarnings  TotalPlayers  TotalTournaments
# 0         24963.85            86                72
# 5        774490.96           586               153
# 17       419825.00            79                59
# 25      4652134.83          2065              5891
# 32       772608.87           558              1335
# 33        70589.45            61                57

# %%
# set variable for gaame under the new data set
# redefined total tournaments under new data set
gg = dg.Game.to_list()
tg = dg.TotalTournaments.to_list()

# graphing in horizontal bar graph of tournaments and games
plt.barh(gg, tg)
plt.xlabel('Tournaments')
plt.ylabel('Game')
plt.title('Tournaments Per Game')
plt.savefig('../figures/Strategy_game-tour_barh.png')

# %%
# # compiled new data data set for strategy games only
# defined new set with variable
df = data[data.Genre == 'Multiplayer Online Battle Arena']
df
# Out:
#                           Game  ReleaseDate                            Genre  \
# 138             Arena of Valor         2015  Multiplayer Online Battle Arena
# 139                 Battlerite         2016  Multiplayer Online Battle Arena
# 140        Bloodline Champions         2011  Multiplayer Online Battle Arena
# 141       Creative Destruction         2018  Multiplayer Online Battle Arena
# 142    Defense of the Ancients         2003  Multiplayer Online Battle Arena
# 143                      Dofus         2004  Multiplayer Online Battle Arena
# 144                     Dota 2         2013  Multiplayer Online Battle Arena
# 145       Heavy Metal Machines         2017  Multiplayer Online Battle Arena
# 146          Heroes of Newerth         2010  Multiplayer Online Battle Arena
# 147        Heroes of the Storm         2015  Multiplayer Online Battle Arena
# 148                Hyper Scape         2020  Multiplayer Online Battle Arena
# ...

# %%
# set variable for gaame under the new data set
# redefined total earnings under new data set
g = df.Game.to_list()
e = df.TotalEarnings.to_list()

# graphing in horizontal bar graph of games and earnings
plt.barh(g, e)
plt.ylabel('Games')
plt.xlabel('Total Earnings [millions]')
plt.title('Earnings Per Game')
plt.savefig('../figures/MultiOnlineBattleArean_game-earn_barh.png')
